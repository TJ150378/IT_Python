# %%
#install library pandas
import pandas as pd

#url="https://github.com/ssukree/testrd/raw/master/data.xlsx"
#df = pd.read_excel(url)

#df = pd.read_excel(filename)
df = pd.read_excel('C:/Users/TJ150378/data_emer.xlsx') #read fine full path
df.head()  #show header file
# Out:
#   ชื่อเทศกาล  รหัสจังหวัด        จังหวัด  รหัส รพ.  \
# 0  ปีใหม่ 51           10  กรุงเทพมหานคร     11630
# 1  ปีใหม่ 51           10  กรุงเทพมหานคร     11548
# 2  ปีใหม่ 51           10  กรุงเทพมหานคร     11548
# 3  ปีใหม่ 51           10  กรุงเทพมหานคร     11548
# 4  ปีใหม่ 51           10  กรุงเทพมหานคร     11548
#
#   ชื่อโรงพยาบาลที่รับผู้บาดเจ็บ  วันที่เกิดเหตุ    เวลาเกิดเหตุ   เพศ  อายุ  \
# 0                       กรุงเทพ               3  12:01-13:00 น.  หญิง    54
# 1              กรุงเทพคริสเตียน               2  21:01-22:00 น.  หญิง    13
# 2              กรุงเทพคริสเตียน              31  03:01-04:00 น.  หญิง     0
# 3              กรุงเทพคริสเตียน              31  03:01-04:00 น.  หญิง     0
# 4              กรุงเทพคริสเตียน              31  03:01-04:00 น.   ชาย     0
#
#   ถนนที่เกิดเหตุ      สถานะ    รถผู้บาดเจ็บ     รถคู่กรณี  มาตรการ  \
# 0        ในเมือง  ผู้ชับขี่  รถเก๋ง/แท็กซี่  ไม่มี/ล้มเอง  เข็มขัด
# ...

# %%
df.head()
# Out:
#   ชื่อเทศกาล  รหัสจังหวัด        จังหวัด  รหัส รพ.  \
# 0  ปีใหม่ 51           10  กรุงเทพมหานคร     11630
# 1  ปีใหม่ 51           10  กรุงเทพมหานคร     11548
# 2  ปีใหม่ 51           10  กรุงเทพมหานคร     11548
# 3  ปีใหม่ 51           10  กรุงเทพมหานคร     11548
# 4  ปีใหม่ 51           10  กรุงเทพมหานคร     11548
#
#   ชื่อโรงพยาบาลที่รับผู้บาดเจ็บ  วันที่เกิดเหตุ    เวลาเกิดเหตุ   เพศ  อายุ  \
# 0                       กรุงเทพ               3  12:01-13:00 น.  หญิง    54
# 1              กรุงเทพคริสเตียน               2  21:01-22:00 น.  หญิง    13
# 2              กรุงเทพคริสเตียน              31  03:01-04:00 น.  หญิง     0
# 3              กรุงเทพคริสเตียน              31  03:01-04:00 น.  หญิง     0
# 4              กรุงเทพคริสเตียน              31  03:01-04:00 น.   ชาย     0
#
#   ถนนที่เกิดเหตุ      สถานะ    รถผู้บาดเจ็บ     รถคู่กรณี  มาตรการ  \
# 0        ในเมือง  ผู้ชับขี่  รถเก๋ง/แท็กซี่  ไม่มี/ล้มเอง  เข็มขัด
# ...

# %%
df.tail()
# Out:
#        ชื่อเทศกาล  รหัสจังหวัด จังหวัด  รหัส รพ.  \
# 214945  ปีใหม่ 58           97  บึงกาฬ     11049
# 214946  ปีใหม่ 58           97  บึงกาฬ     11049
# 214947  ปีใหม่ 58           97  บึงกาฬ     11049
# 214948  ปีใหม่ 58           97  บึงกาฬ     11049
# 214949  ปีใหม่ 58           97  บึงกาฬ     11049
#
#        ชื่อโรงพยาบาลที่รับผู้บาดเจ็บ  วันที่เกิดเหตุ    เวลาเกิดเหตุ   เพศ  \
# 214945                       ศรีวิไล              31  09:01-10:00 น.   ชาย
# 214946                       ศรีวิไล              30  16:01-17:00 น.  หญิง
# 214947                       ศรีวิไล              30  24:01-01:00 น.   ชาย
# 214948                       ศรีวิไล              31  14:01-15:00 น.   ชาย
# 214949                       ศรีวิไล               5  15:01-16:00 น.   ชาย
#
#         อายุ ถนนที่เกิดเหตุ       สถานะ  รถผู้บาดเจ็บ      รถคู่กรณี  มาตรการ  \
# 214945     3           ชนบท  คนเดินเท้า  ไม่มี/ล้มเอง    จักรยานยนต์   ไม่ใส่
# ...

# %%
print(df.columns)
print(df.index)
print(len(df.index))
# Out:
# Index(['ชื่อเทศกาล', 'รหัสจังหวัด', 'จังหวัด', 'รหัส รพ.',
#        'ชื่อโรงพยาบาลที่รับผู้บาดเจ็บ', 'วันที่เกิดเหตุ', 'เวลาเกิดเหตุ',
#        'เพศ', 'อายุ', 'ถนนที่เกิดเหตุ', 'สถานะ', 'รถผู้บาดเจ็บ', 'รถคู่กรณี',
#        'มาตรการ', 'การดื่มสุรา', 'การนำส่ง', 'Refer-Admit', 'ผลการรักษา',
#        'จำนวนวันรักษา'],
#       dtype='object')
# RangeIndex(start=0, stop=214950, step=1)
# 214950

# %%
print(df.dtypes)
# Out:
# ชื่อเทศกาล                       object
# รหัสจังหวัด                       int64
# จังหวัด                          object
# รหัส รพ.                          int64
# ชื่อโรงพยาบาลที่รับผู้บาดเจ็บ    object
# วันที่เกิดเหตุ                    int64
# เวลาเกิดเหตุ                     object
# เพศ                              object
# อายุ                              int64
# ถนนที่เกิดเหตุ                   object
# สถานะ                            object
# รถผู้บาดเจ็บ                     object
# รถคู่กรณี                        object
# มาตรการ                          object
# การดื่มสุรา                      object
# การนำส่ง                         object
# Refer-Admit                      object
# ผลการรักษา                       object
# จำนวนวันรักษา                     int64
# dtype: object

# %%
print(df ['อายุ'].describe())
# Out:
# count    214950.000000
# mean         28.861433
# std          16.402318
# min           0.000000
# 25%          17.000000
# 50%          25.000000
# 75%          39.000000
# max          99.000000
# Name: อายุ, dtype: float64

# %%
df['ผลการรักษา']
# Out:
# 0                             ทุเลา/หาย
# 1                             ทุเลา/หาย
# 2                             ทุเลา/หาย
# 3                             ทุเลา/หาย
# 4                             ทุเลา/หาย
# 5                             ทุเลา/หาย
# 6                             ทุเลา/หาย
# 7                             ทุเลา/หาย
# 8                             ทุเลา/หาย
# 9                             ทุเลา/หาย
# 10                            ทุเลา/หาย
# 11                            ทุเลา/หาย
# 12                            ทุเลา/หาย
# 13                            ทุเลา/หาย
# 14                            ทุเลา/หาย
# 15                            ทุเลา/หาย
# 16                            ทุเลา/หาย
# 17                            ทุเลา/หาย
# 18                            ทุเลา/หาย
# 19                            ทุเลา/หาย
# 20                            ทุเลา/หาย
# 21                            ทุเลา/หาย
# 22                            ทุเลา/หาย
# ...

# %%
import random
data = [random.randint(0,100) for i in range (50)]
print(data)
print(set (data))
print(set(df['ผลการรักษา']))
# Out:
# [91, 15, 74, 84, 29, 78, 52, 32, 33, 42, 76, 55, 61, 83, 42, 25, 94, 41, 83, 1, 39, 28, 29, 88, 64, 2, 75, 43, 66, 82, 50, 14, 44, 0, 3, 47, 14, 92, 17, 51, 85, 83, 53, 57, 62, 70, 6, 53, 97, 85]
# {0, 1, 2, 3, 6, 14, 15, 17, 25, 28, 29, 32, 33, 39, 41, 42, 43, 44, 47, 50, 51, 52, 53, 55, 57, 61, 62, 64, 66, 70, 74, 75, 76, 78, 82, 83, 84, 85, 88, 91, 92, 94, 97}
# {'ทุเลา/หาย', 'ตายที่เกิดเหตุ', 'ตายระหว่างส่งต่อ', 'ตายระหว่างนำส่ง', 'ตายที่ห้องฉุกเฉิน', 'ตายในตึกภายใน 24 ชม. หลังเหตุ', 'ตายในตึกหลัง 24 ชม. - 30 วัน'}

# %%
df[df['อายุ']==17]
# Out:
#        ชื่อเทศกาล  รหัสจังหวัด        จังหวัด  รหัส รพ.  \
# 27      ปีใหม่ 51           10  กรุงเทพมหานคร     11668
# 46      ปีใหม่ 51           10  กรุงเทพมหานคร     11583
# 64      ปีใหม่ 51           10  กรุงเทพมหานคร     11581
# 72      ปีใหม่ 51           10  กรุงเทพมหานคร     11581
# 171     ปีใหม่ 51           10  กรุงเทพมหานคร     11656
# 226     ปีใหม่ 51           10  กรุงเทพมหานคร     13756
# 237     ปีใหม่ 51           10  กรุงเทพมหานคร     13756
# 248     ปีใหม่ 51           10  กรุงเทพมหานคร     13756
# 319     ปีใหม่ 51           10  กรุงเทพมหานคร     11558
# 327     ปีใหม่ 51           10  กรุงเทพมหานคร     11558
# 347     ปีใหม่ 51           10  กรุงเทพมหานคร     11539
# 352     ปีใหม่ 51           10  กรุงเทพมหานคร     11539
# 361     ปีใหม่ 51           10  กรุงเทพมหานคร     11539
# 372     ปีใหม่ 51           10  กรุงเทพมหานคร     11539
# 408     ปีใหม่ 51           10  กรุงเทพมหานคร     15051
# 423     ปีใหม่ 51           10  กรุงเทพมหานคร     14567
# ...

# %%
import random
import collections

data = [random.randint(0,100) for i in range (50)]
print(collections.Counter(df['ผลการรักษา']))
print(collections.Counter(df['ผลการรักษา']).most_common())
# Out:
# Counter({'ทุเลา/หาย': 211386, 'ตายที่เกิดเหตุ': 2137, 'ตายที่ห้องฉุกเฉิน': 492, 'ตายในตึกภายใน 24 ชม. หลังเหตุ': 463, 'ตายในตึกหลัง 24 ชม. - 30 วัน': 302, 'ตายระหว่างนำส่ง': 111, 'ตายระหว่างส่งต่อ': 59})
# [('ทุเลา/หาย', 211386), ('ตายที่เกิดเหตุ', 2137), ('ตายที่ห้องฉุกเฉิน', 492), ('ตายในตึกภายใน 24 ชม. หลังเหตุ', 463), ('ตายในตึกหลัง 24 ชม. - 30 วัน', 302), ('ตายระหว่างนำส่ง', 111), ('ตายระหว่างส่งต่อ', 59)]

# %%
df1=df[df['ผลการรักษา']=='ตายที่เกิดเหตุ']
collections.Counter(df1['ถนนที่เกิดเหตุ'])
# Out:
# Counter({'ชนบท': 749, 'ทางหลวง': 1181, 'ในเมือง': 169, 'ไม่ทราบ': 38})

# %%
df1=df[df['ผลการรักษา']=='ตายที่เกิดเหตุ']
collections.Counter(df1['รถผู้บาดเจ็บ'])
# Out:
# Counter({'จักรยานยนต์': 1321,
#          'ปิคอัพ': 288,
#          'รถจักรยาน': 77,
#          'รถตู้': 13,
#          'รถบรรทุก': 21,
#          'รถเก๋ง/แท็กซี่': 139,
#          'รถโดยสาร 4 ล้อ': 7,
#          'รถโดยสารใหญ่': 11,
#          'สามล้อถีบ': 2,
#          'สามล้อเครื่อง': 24,
#          'อื่นๆ': 48,
#          'ไม่ทราบ': 25,
#          'ไม่มี/ล้มเอง': 161})

# %%
df1=df[df['ผลการรักษา']=='ตายที่เกิดเหตุ']
collections.Counter(df1['เวลาเกิดเหตุ'])
# Out:
# Counter({'01:01-02:00 น.': 96,
#          '02:01-03:00 น.': 76,
#          '03:01-04:00 น.': 70,
#          '04:01-05:00 น.': 73,
#          '05:01-06:00 น.': 67,
#          '06:01-07:00 น.': 52,
#          '07:01-08:00 น.': 68,
#          '08:01-09:00 น.': 74,
#          '09:01-10:00 น.': 57,
#          '10:01-11:00 น.': 51,
#          '11:01-12:00 น.': 65,
#          '12:01-13:00 น.': 59,
#          '13:01-14:00 น.': 66,
#          '14:01-15:00 น.': 84,
#          '15:01-16:00 น.': 90,
#          '16:01-17:00 น.': 92,
#          '17:01-18:00 น.': 112,
#          '18:01-19:00 น.': 151,
#          '19:01-20:00 น.': 142,
#          '20:01-21:00 น.': 137,
#          '21:01-22:00 น.': 114,
#          '22:01-23:00 น.': 109,
#          '23:01-24:00 น.': 75,
#          '24:01-01:00 น.': 126,
#          'ไม่ทราบ': 31})

# %%
import collections
print(collections.Counter(df['ผลการรักษา']))
filtered_df = df[df['การดื่มสุรา']=='ดื่ม']
filtered_df1 = df[df['การดื่มสุรา']=='ไม่ดื่ม']
road_df = df[df['']]
print(collections.Counter(filtered_df['ผลการรักษา']))
print(collections.Counter(filtered_df1['ผลการรักษา']))
# Out:
# Counter({'ทุเลา/หาย': 211386, 'ตายที่เกิดเหตุ': 2137, 'ตายที่ห้องฉุกเฉิน': 492, 'ตายในตึกภายใน 24 ชม. หลังเหตุ': 463, 'ตายในตึกหลัง 24 ชม. - 30 วัน': 302, 'ตายระหว่างนำส่ง': 111, 'ตายระหว่างส่งต่อ': 59})
# Counter({'ทุเลา/หาย': 74365, 'ตายที่เกิดเหตุ': 522, 'ตายในตึกภายใน 24 ชม. หลังเหตุ': 189, 'ตายที่ห้องฉุกเฉิน': 153, 'ตายในตึกหลัง 24 ชม. - 30 วัน': 142, 'ตายระหว่างนำส่ง': 26, 'ตายระหว่างส่งต่อ': 23})
# Counter({'ทุเลา/หาย': 125290, 'ตายที่เกิดเหตุ': 523, 'ตายในตึกภายใน 24 ชม. หลังเหตุ': 162, 'ตายที่ห้องฉุกเฉิน': 144, 'ตายในตึกหลัง 24 ชม. - 30 วัน': 96, 'ตายระหว่างนำส่ง': 41, 'ตายระหว่างส่งต่อ': 21})

# %%
import collections
print(collections.Counter(df['ผลการรักษา']))
filtered_df = df[df['รถผู้บาดเจ็บ']=='ปิคอัพ']
road_df = df[df['ถนนที่เกิดเหตุ']=='ทางหลวง']
print(collections.Counter(filtered_df['ผลการรักษา']))
print(collections.Counter(road_df['ผลการรักษา']))
# Out:
# Counter({'ทุเลา/หาย': 211386, 'ตายที่เกิดเหตุ': 2137, 'ตายที่ห้องฉุกเฉิน': 492, 'ตายในตึกภายใน 24 ชม. หลังเหตุ': 463, 'ตายในตึกหลัง 24 ชม. - 30 วัน': 302, 'ตายระหว่างนำส่ง': 111, 'ตายระหว่างส่งต่อ': 59})
# Counter({'ทุเลา/หาย': 12476, 'ตายที่เกิดเหตุ': 288, 'ตายที่ห้องฉุกเฉิน': 57, 'ตายในตึกภายใน 24 ชม. หลังเหตุ': 44, 'ตายในตึกหลัง 24 ชม. - 30 วัน': 19, 'ตายระหว่างส่งต่อ': 9, 'ตายระหว่างนำส่ง': 9})
# Counter({'ทุเลา/หาย': 59432, 'ตายที่เกิดเหตุ': 1181, 'ตายที่ห้องฉุกเฉิน': 259, 'ตายในตึกภายใน 24 ชม. หลังเหตุ': 207, 'ตายในตึกหลัง 24 ชม. - 30 วัน': 102, 'ตายระหว่างนำส่ง': 50, 'ตายระหว่างส่งต่อ': 27})

# %%
import collections
print(collections.Counter(df['ผลการรักษา']))
car_df = df[df['รถผู้บาดเจ็บ']=='ปิคอัพ']
motor_df = car_df[car_df['ถนนที่เกิดเหตุ']=='ทางหลวง'] 
motor_df1 = car_df[car_df['ถนนที่เกิดเหตุ']=='ชนบท'] 
motor_df2 = car_df[car_df['ถนนที่เกิดเหตุ']=='ในเมือง'] 
motor_df3 = car_df[car_df['ถนนที่เกิดเหตุ']=='ไม่ทราบ'] 
print(collections.Counter(car_df['ผลการรักษา']))
print(collections.Counter(motor_df['ผลการรักษา']))
print(collections.Counter(motor_df1['ผลการรักษา']))
print(collections.Counter(motor_df2['ผลการรักษา']))
print(collections.Counter(motor_df3['ผลการรักษา']))
# Out:
# Counter({'ทุเลา/หาย': 211386, 'ตายที่เกิดเหตุ': 2137, 'ตายที่ห้องฉุกเฉิน': 492, 'ตายในตึกภายใน 24 ชม. หลังเหตุ': 463, 'ตายในตึกหลัง 24 ชม. - 30 วัน': 302, 'ตายระหว่างนำส่ง': 111, 'ตายระหว่างส่งต่อ': 59})
# Counter({'ทุเลา/หาย': 12476, 'ตายที่เกิดเหตุ': 288, 'ตายที่ห้องฉุกเฉิน': 57, 'ตายในตึกภายใน 24 ชม. หลังเหตุ': 44, 'ตายในตึกหลัง 24 ชม. - 30 วัน': 19, 'ตายระหว่างส่งต่อ': 9, 'ตายระหว่างนำส่ง': 9})
# Counter({'ทุเลา/หาย': 6977, 'ตายที่เกิดเหตุ': 186, 'ตายที่ห้องฉุกเฉิน': 38, 'ตายในตึกภายใน 24 ชม. หลังเหตุ': 28, 'ตายในตึกหลัง 24 ชม. - 30 วัน': 11, 'ตายระหว่างนำส่ง': 5, 'ตายระหว่างส่งต่อ': 3})
# Counter({'ทุเลา/หาย': 4234, 'ตายที่เกิดเหตุ': 84, 'ตายที่ห้องฉุกเฉิน': 14, 'ตายในตึกภายใน 24 ชม. หลังเหตุ': 10, 'ตายระหว่างส่งต่อ': 6, 'ตายในตึกหลัง 24 ชม. - 30 วัน': 6, 'ตายระหว่างนำส่ง': 3})
# Counter({'ทุเลา/หาย': 1018, 'ตายที่เกิดเหตุ': 16, 'ตายที่ห้องฉุกเฉิน': 4, 'ตายในตึกภายใน 24 ชม. หลังเหตุ': 3, 'ตายในตึกหลัง 24 ชม. - 30 วัน': 1})
# ...

# %%
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (15,15)
#df['อายุ'].value_counts()
#df['อายุ'].value_counts().plot.bar()
df['อายุ'].value_counts().sort_index().plot.bar()
plt.show()

# %%
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (15,15)
#df['อายุ'].value_counts()
#df['อายุ'].value_counts().plot.bar()
filtered_df = df[df['ผลการรักษา']!='ทุเลา/หาย']
filtered_df['อายุ'].value_counts().sort_index().plot.bar()


plt.show()

# %%
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (15,15)
#df['อายุ'].value_counts()
#df['อายุ'].value_counts().plot.bar()
#filtered_df = df[df['ผลการรักษา']!='ทุเลา/หาย']
#filtered_df['อายุ'].value_counts().sort_index().plot.bar()
df[df['ผลการรักษา']!='ทุเลา/หาย']['อายุ'].value_counts().sort_index().plot.bar()
plt.show()

# %%
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (15,15)
#df['อายุ'].value_counts()
#df['อายุ'].value_counts().plot.bar()
#filtered_df = df[df['ผลการรักษา']!='ทุเลา/หาย']
#filtered_df['อายุ'].value_counts().sort_index().plot.bar()
#df[df['ผลการรักษา']!='ทุเลา/หาย']['อายุ'].value_counts().sort_index().plot.bar()
df[df['ผลการรักษา']!='ทุเลา/หาย']['เวลาเกิดเหตุ'].value_counts().sort_index().plot.bar()
plt.show()

# %%
import matplotlib.pyplot as plt
#plt.rcParams['font.sans-serif'] = ['Tahoma']
plt.rcParams['figure.figsize'] = (15,15)
#df['อายุ'].value_counts()
#df['อายุ'].value_counts().plot.bar()
#filtered_df = df[df['ผลการรักษา']!='ทุเลา/หาย']
#filtered_df['อายุ'].value_counts().sort_index().plot.bar()
#df[df['ผลการรักษา']!='ทุเลา/หาย']['อายุ'].value_counts().sort_index().plot.bar()
df[df['ผลการรักษา']!='ทุเลา/หาย']['เวลาเกิดเหตุ'].value_counts().sort_index().plot.bar()
plt.show()

# %%
import matplotlib.pyplot as plt
#plt.rcParams['font.sans-serif'] = ['Tahoma']
#plt.rcParams['figure.figsize'] = (15,15)
#df['อายุ'].value_counts()
#df['อายุ'].value_counts().plot.bar()
#filtered_df = df[df['ผลการรักษา']!='ทุเลา/หาย']
#filtered_df['อายุ'].value_counts().sort_index().plot.bar()
#df[df['ผลการรักษา']!='ทุเลา/หาย']['อายุ'].value_counts().sort_index().plot.bar()
#df[df['ผลการรักษา']!='ทุเลา/หาย']['เวลาเกิดเหตุ'].value_counts().sort_index().plot.bar()
#plt.show()
s = df.groupby(['รถผู้บาดเจ็บ'])['อายุ'].agg('mean')
s
# Out:
# รถผู้บาดเจ็บ
# จักรยานยนต์       28.377281
# ปิคอัพ            31.950550
# รถจักรยาน         29.159058
# รถตู้             33.092559
# รถบรรทุก          34.118280
# รถเก๋ง/แท็กซี่    32.018049
# รถโดยสาร 4 ล้อ    31.661682
# รถโดยสารใหญ่      31.755149
# สามล้อถีบ         37.070270
# สามล้อเครื่อง     36.094439
# อื่นๆ             31.170163
# ไม่ทราบ           24.245902
# ไม่มี/ล้มเอง      27.912728
# Name: อายุ, dtype: float64

# %%
s =df[df['สถานะ']=='ผู้ชับขี่'].groupby(['รถผู้บาดเจ็บ'])['อายุ'].agg('mean')
s
# Out:
# รถผู้บาดเจ็บ
# จักรยานยนต์       29.984104
# ปิคอัพ            36.083681
# รถจักรยาน         30.964416
# รถตู้             38.006289
# รถบรรทุก          37.310231
# รถเก๋ง/แท็กซี่    34.277203
# รถโดยสาร 4 ล้อ    36.573171
# รถโดยสารใหญ่      40.236842
# สามล้อถีบ         40.318182
# สามล้อเครื่อง     40.968165
# อื่นๆ             38.226378
# ไม่ทราบ           31.405316
# ไม่มี/ล้มเอง      29.229253
# Name: อายุ, dtype: float64

# %%
filtered_df=df[df['อายุ'] > 0]
filtered_df=filtered_df[filtered_df['อายุ'] < 99]
s =filtered_df[filtered_df['สถานะ']=='ผู้ชับขี่'].groupby(['รถผู้บาดเจ็บ'])['อายุ'].agg('max')
s
# Out:
# รถผู้บาดเจ็บ
# จักรยานยนต์       97
# ปิคอัพ            79
# รถจักรยาน         94
# รถตู้             67
# รถบรรทุก          66
# รถเก๋ง/แท็กซี่    87
# รถโดยสาร 4 ล้อ    71
# รถโดยสารใหญ่      60
# สามล้อถีบ         85
# สามล้อเครื่อง     85
# อื่นๆ             81
# ไม่ทราบ           75
# ไม่มี/ล้มเอง      84
# Name: อายุ, dtype: int64
